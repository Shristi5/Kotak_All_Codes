# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer

# Load the Excel file

data = pd.read_excel(r"C:\Users\shris\Desktop\neutral.xlsx", )

# Extract the comments from the DataFrame
comments = df['Comments'].tolist()

# Create a TF-IDF vectorizer
vectorizer = TfidfVectorizer()

# Calculate TF-IDF scores for all words in the comments
tfidf_matrix = vectorizer.fit_transform(comments)

# Get list of feature names (words)
feature_names = list(vectorizer.vocabulary_.keys())

# Calculate the average TF-IDF score for each word across all comments
avg_tfidf_scores = tfidf_matrix.mean(axis=0)

# Convert average scores to a list
avg_tfidf_scores = avg_tfidf_scores.tolist()[0]
threshold = 0.1





# Create a new list of important words based on the threshold
important_words = [feature_names[i] for i, score in enumerate(avg_tfidf_scores) if score > threshold]


# Get the indices of the top 300 words with the highest TF-IDF scores
top_indices = sorted(range(len(avg_tfidf_scores)), key=lambda i: avg_tfidf_scores[i], reverse=True)[:300]

# Get the top 300 words with the highest TF-IDF scores
top_words = [feature_names[i] for i in top_indices]

# Print the top 300 words with the highest TF-IDF scores
print('Top 300 words with the highest TF-IDF scores:')
print(top_words)
print('Important words:')
print(important_words)
print('Dimensions of the TF-IDF matrix:', tfidf_matrix.shape)
# Out:
# Top 300 words with the highest TF-IDF scores:
# ['send', 'strategy', 'welcome', 'mrsandeep', 'offer', 'beneficiary', 'pathetic', 'mere', 'cost', 'cb', 'suck', 'warningdont', 'understand', 'enough', 'failed', 'execute', 'company', 'older', 'please', 'recorded', 'rd', 'exorbitant', 'guideline', 'history', 'month', 'talked', 'executive', 'whether', 'usually', 'jo', 'indian', 'correctly', 'detect', 'cce', 'withdraw', 'stopped', 'talking', 'mob', 'bombard', 'second', 'offered', 'via', 'line', 'said', 'even', 'hiddenuninformed', 'south', 'product', 'atleast', 'shouting', 'maintenance', 'saurashtra', 'loyal', 'server', 'suddenly', 'debuted', 'saying', 'helptried', 'system', 'activated', 'seen', 'nagalakshmi', 'without', 'body', 'ek', 'type', 'tha', 'fraud', 'nricustomer', 'irritating', 'sending', 'near', 'rendered', 'told', 'lot', 'customize', 'residential', 'forward', 'increase', 'swath', 'confirm', 'someone', 'ka', 'connected', 'technical', 'eligibility', 'collect', 'appropriate', 'nov', 'that', 'waive', 'earned', 'thenikennadyattaching', 'finally', 'dutyall', 'installment', 'half', 'date', 'facing', 'nearest', 'con', 'misshaping', 'choose', 'specific', 'backed', 'plenty', 'ever', 'rating', 'series', 'unpleasant', 'hard', 'corporate', 'seems', 'cooling', 'disgusting', 'travel', 'comment', 'itn', 'made', 'last', 'ky', 'period', 'reminder', 'negative', 'cancel', 'compared', 'department', 'point', 'moreover', 'structure', 'close', 'immediately', 'twice', 'suspicious', 'put', 'xxxxxxxxxxxxxxicicibankcom', 'amazon', 'cleaner', 'clue', 'jawa', 'must', 'survive', 'amount', 'nowadays', 'worse', 'taking', 'team', 'website', 'visit', 'appears', 'trust', 'hidden', 'frequently', 'sab', 'overtime', 'everything', 'accepting', 'chain', 'going', 'centre', 'required', 'deducted', 'sr', 'updated', 'care', 'good', 'clarification', 'support', 'handle', 'cash', 'automatically', 'harass', 'refund', 'confirmation', 'loan', 'chance', 'basis', 'considered', 'ahin', 'relative', 'detail', 'signed', 'closing', 'premium', 'cheque', 'fall', 'correct', 'commitment', 'kia', 'annual', 'payment', 'something', 'versa', 'sardabaag', 'take', 'gateway', 'impossible', 'fool', 'collected', 'app', 'provider', 'wa', 'investment', 'language', 'no', 'class', 'night', 'bat', 'hour', 'neither', 'token', 'release', 'felt', 'digital', 'registered', 'bastard', 'bother', 'branchthey', 'private', 'associated', 'thrice', 'typing', 'expects', 'inefficient', 'mopmode', 'relating', 'wrongly', 'closed', 'used', 'process', 'expected', 'usesapp', 'assured', 'documentation', 'providing', 'bible', 'international', 'bill', 'etc', 'banker', 'concern', 'automaticallysometimes', 'ru', 'wrong', 'rbi', 'boy', 'getting', 'bal', 'account', 'except', 'ina', 'commit', 'train', 'petty', 'credential', 'feel', 'back', 'redeem', 'rude', 'semana', 'denial', 'rediculas', 'cac', 'whole', 'properly', 'mistake', 'false', 'low', 'using', 'score', 'cancelled', 'contacted', 'poor', 'lowest', 'survived', 'notification', 'parent', 'saving', 'debit', 'per', 'much', 'detection', 'enabling', 'hopeless', 'rendering', 'moment', 'usa', 'writing', 'surely', 'experienced', 'late', 'ear', 'sm', 'top', 'career', 'add', 'deliberately', 'rate', 'advertisement', 'delaware']
# Important words:
# []
# Dimensions of the TF-IDF matrix: (100, 1157)

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
import seaborn as sns
import matplotlib.pyplot as plt

# Load the Excel file

data = pd.read_excel(r"C:\Users\shris\Desktop\neutral.xlsx", )

# Extract the comments from the DataFrame
comments = df['Comments'].tolist()

# Create a TF-IDF vectorizer
vectorizer = TfidfVectorizer()

# Calculate TF-IDF scores for all words in the comments
tfidf_matrix = vectorizer.fit_transform(comments)

# Get list of feature names (words)
feature_names = list(vectorizer.vocabulary_.keys())

# Convert the TF-IDF matrix to a dense matrix
tfidf_matrix_dense = tfidf_matrix.todense()

# Plot a heatmap of the TF-IDF matrix
sns.heatmap(tfidf_matrix_dense, cmap='viridis')

# Set the x-axis labels to the feature names
plt.xticks(range(len(feature_names)), feature_names, rotation=90)

# Set the y-axis labels to the document indices
plt.yticks(range(len(comments)), range(1, len(comments) + 1), rotation=0)

# Show the plot
plt.show()
